# %% [markdown]
# # i) ToyotaCorolla.csv

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
# i) Read the dataset.
df1 = pd.read_csv("ToyotaCorolla.csv",encoding='ISO-8859-1')
df1
# Out:
#         Id                                              Model  Price  \
# 0        1      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500
# 1        2      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750
# 2        3      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950
# 3        4      TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950
# 4        5        TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750
# ...    ...                                                ...    ...
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color   Color  \
# ...

# %%
# ii) Display first 5 and last 5 records.
df1.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color   Color  Automatic  \
# 0         10      2002  46986    Diesel  90          1    Blue          0
# 1         10      2002  72937    Diesel  90          1  Silver          0
# 2          9      2002  41711    Diesel  90          1    Blue          0
# 3          7      2002  48000    Diesel  90          0   Black          0
# 4          3      2002  38500    Diesel  90          0   Black          0
#
#      cc  Doors  Cylinders  Gears  Quarterly_Tax  Weight  Mfr_Guarantee  \
# ...

# %%
df1.tail()
# Out:
#         Id                                              Model  Price  \
# 1431  1438         TOYOTA Corolla 1.3 16V HATCHB G6 2/3-Doors   7500
# 1432  1439  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...  10845
# 1433  1440  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   8500
# 1434  1441  TOYOTA Corolla 1.3 16V HATCHB LINEA TERRA 2/3-...   7250
# 1435  1442        TOYOTA Corolla 1.6 LB LINEA TERRA 4/5-Doors   6950
#
#       Age_08_04  Mfg_Month  Mfg_Year     KM Fuel_Type   HP  Met_Color  Color  \
# 1431         69         12      1998  20544    Petrol   86          1   Blue
# 1432         72          9      1998  19000    Petrol   86          0   Grey
# 1433         71         10      1998  17016    Petrol   86          0   Blue
# 1434         70         11      1998  16916    Petrol   86          1   Grey
# 1435         76          5      1998      1    Petrol  110          0  Green
#
#       Automatic    cc  Doors  Cylinders  Gears  Quarterly_Tax  Weight  \
# ...

# %%
# iii) Display info and describe the dataset.
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 38 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Id                1436 non-null   int64
#  1   Model             1436 non-null   object
#  2   Price             1436 non-null   int64
#  3   Age_08_04         1436 non-null   int64
#  4   Mfg_Month         1436 non-null   int64
#  5   Mfg_Year          1436 non-null   int64
#  6   KM                1436 non-null   int64
#  7   Fuel_Type         1436 non-null   object
#  8   HP                1436 non-null   int64
#  9   Met_Color         1436 non-null   int64
#  10  Color             1436 non-null   object
#  11  Automatic         1436 non-null   int64
#  12  cc                1436 non-null   int64
#  13  Doors             1436 non-null   int64
#  14  Cylinders         1436 non-null   int64
#  15  Gears             1436 non-null   int64
# ...

# %%
# iv) Find out null values.
df.isna().sum()
# Out:
# Id                  0
# Model               0
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Color               0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# dtype: int64

# %%
# v) Plot Various graphs. e.g. barchart, scatterplot, histogram, lineplot, pairplot and all other.

# %%
#3)scatterplot

plt.scatter()

# %%
# 2)pie

plt.pie(x=df1["Color"].value_counts(), labels=df1["Color"].unique())
plt.title('Colour Of Cars')
plt.show()

# %%
# 1)scatterplot
sns.scatterplot(x=df1["Fuel_Type"],y=df1["Color"])
# Out:
# <AxesSubplot: xlabel='Fuel_Type', ylabel='Color'>

# %%
# vii)  Find out correlation and covariance in the dataset.
df1.corr()
# Out:
#                         Id     Price  Age_08_04  Mfg_Month  Mfg_Year  \
# Id                1.000000 -0.738250   0.906132   0.043742 -0.919523
# Price            -0.738250  1.000000  -0.876590  -0.018138  0.885159
# Age_08_04         0.906132 -0.876590   1.000000  -0.123255 -0.983661
# Mfg_Month         0.043742 -0.018138  -0.123255   1.000000 -0.057416
# Mfg_Year         -0.919523  0.885159  -0.983661  -0.057416  1.000000
# KM                0.273298 -0.569960   0.505672  -0.020630 -0.504974
# HP               -0.109375  0.314990  -0.156622  -0.039312  0.164697
# Met_Color        -0.079713  0.108905  -0.108150   0.030266  0.103310
# Automatic         0.066265  0.033081   0.031717   0.009146 -0.033567
# cc               -0.117704  0.126389  -0.098084   0.037387  0.091892
# Doors            -0.130207  0.185326  -0.148359  -0.012069  0.151442
# Cylinders              NaN       NaN        NaN        NaN       NaN
# Gears            -0.043343  0.063104  -0.005364  -0.013063  0.007766
# ...

# %%
df1.cov()
# Out:
#                             Id         Price      Age_08_04    Mfg_Month  \
# Id                1.734530e+05 -1.115161e+06    7019.317896    61.103588
# Price            -1.115161e+06  1.315487e+07  -59136.108946  -220.654157
# Age_08_04         7.019318e+03 -5.913611e+04     345.959566    -7.689404
# Mfg_Month         6.110359e+01 -2.206542e+02      -7.689404    11.249887
# Mfg_Year         -5.900351e+02  4.946397e+03     -28.189180    -0.296707
# KM                4.269068e+06 -7.753428e+07  352766.779610 -2595.237409
# HP               -6.824182e+02  1.711524e+04     -43.642398    -1.975363
# Met_Color        -1.555736e+01  1.851004e+02      -0.942659     0.047571
# Automatic         6.332125e+00  2.752895e+01       0.135355     0.007039
# cc               -2.080392e+04  1.945428e+05    -774.232722    53.217136
# Doors            -5.166177e+01  6.403599e+02      -2.628892    -0.038564
# Cylinders         0.000000e+00  0.000000e+00       0.000000     0.000000
# ...

# %% [markdown]
# # ii) Engine.csv

# %%
#i) Read the dataset.
df2 = pd.read_csv("Engine.csv.csv")
df2
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0            2.0          4                   8.5           196
# 1            2.4          4                   9.6           221
# 2            1.5          4                   5.9           136
# 3            3.5          6                  11.1           255
# 4            3.5          6                  10.6           244
# ...          ...        ...                   ...           ...
# 1062         3.0          6                  11.8           271
# 1063         3.2          6                  11.5           264
# 1064         3.0          6                  11.8           271
# 1065         3.2          6                  11.3           260
# 1066         3.2          6                  12.8           294
#
# [1067 rows x 4 columns]

# %%
#ii) Display first 5 and last 5 records. 
df2.head()
# Out:
#    ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 0         2.0          4                   8.5           196
# 1         2.4          4                   9.6           221
# 2         1.5          4                   5.9           136
# 3         3.5          6                  11.1           255
# 4         3.5          6                  10.6           244

# %%
df2.tail()
# Out:
#       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# 1062         3.0          6                  11.8           271
# 1063         3.2          6                  11.5           264
# 1064         3.0          6                  11.8           271
# 1065         3.2          6                  11.3           260
# 1066         3.2          6                  12.8           294

# %%
#iii) Display info and describe the dataset.
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 4 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ENGINESIZE            1067 non-null   float64
#  1   CYLINDERS             1067 non-null   int64
#  2   FUELCONSUMPTION_COMB  1067 non-null   float64
#  3   CO2EMISSIONS          1067 non-null   int64
# dtypes: float64(2), int64(2)
# memory usage: 33.5 KB

# %%
df2.describe()
# Out:
#         ENGINESIZE    CYLINDERS  FUELCONSUMPTION_COMB  CO2EMISSIONS
# count  1067.000000  1067.000000           1067.000000   1067.000000
# mean      3.346298     5.794752             11.580881    256.228679
# std       1.415895     1.797447              3.485595     63.372304
# min       1.000000     3.000000              4.700000    108.000000
# 25%       2.000000     4.000000              9.000000    207.000000
# 50%       3.400000     6.000000             10.900000    251.000000
# 75%       4.300000     8.000000             13.350000    294.000000
# max       8.400000    12.000000             25.800000    488.000000

# %%
#iv) Find out null values.
df2.isna().sum()
# Out:
# ENGINESIZE              0
# CYLINDERS               0
# FUELCONSUMPTION_COMB    0
# CO2EMISSIONS            0
# dtype: int64

# %%
# v) Plot Various graphs. e.g. barchart, scatterplot, histogram, lineplot, pairplot and all other.
#1)barchart
# ENGINESIZE,CO2EMISSIONS
#data
x = df2["ENGINESIZE"]
y = df2["CO2EMISSIONS"]

#set the style

#plot the graph
plt.bar(df2["ENGINESIZE"],df2["CO2EMISSIONS"],color='maroon',width=0.4)

#customize the graph
plt.xlabel("Engine Size")
plt.ylabel("CO2 Emissions")
plt.title("Engine and CO2 Emission")

#show the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 2)pie
#data
x = df2["ENGINESIZE"].value_counts()
label = df2["ENGINESIZE"].unique()

#set the style

#plot the graph
plt.pie(x,labels=label)

#customize the graph
plt.title("Engine Size")

#show the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#2)sctterplot
#data
x = df2["ENGINESIZE"]
y = df2["CYLINDERS"]

#set the style

#plot the graph
plt.scatter(df2["ENGINESIZE"],df2["CYLINDERS"])

#customize the graph
plt.xlabel("Engine Size")
plt.ylabel("Cylinders")
plt.title("Engine and Cylinders")

#show the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 4)lineplot
sns.lineplot(data=df2,x='FUELCONSUMPTION_COMB',y='CO2EMISSIONS')
# Out:
# <AxesSubplot: xlabel='FUELCONSUMPTION_COMB', ylabel='CO2EMISSIONS'>

# %%
# 5)pairplot
sns.pairplot(df2)
plt.show()

# %%
# vii)  Find out correlation and covariance in the dataset.
df2.corr()
# Out:
#                       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  \
# ENGINESIZE              1.000000   0.934011              0.819482
# CYLINDERS               0.934011   1.000000              0.776788
# FUELCONSUMPTION_COMB    0.819482   0.776788              1.000000
# CO2EMISSIONS            0.874154   0.849685              0.892129
#
#                       CO2EMISSIONS
# ENGINESIZE                0.874154
# CYLINDERS                 0.849685
# FUELCONSUMPTION_COMB      0.892129
# CO2EMISSIONS              1.000000

# %%
df2.cov()
# Out:
#                       ENGINESIZE  CYLINDERS  FUELCONSUMPTION_COMB  \
# ENGINESIZE              2.004759   2.377054              4.044338
# CYLINDERS               2.377054   3.230817              4.866710
# FUELCONSUMPTION_COMB    4.044338   4.866710             12.149371
# CO2EMISSIONS           78.436588  96.786192            197.062444
#
#                       CO2EMISSIONS
# ENGINESIZE               78.436588
# CYLINDERS                96.786192
# FUELCONSUMPTION_COMB    197.062444
# CO2EMISSIONS           4016.048970

# %% [markdown]
# # iii) delivery_time.csv

# %%
# i) Read the dataset.
df3 = pd.read_csv('delivery_time.csv')
df3
# Out:
#     Delivery Time  Sorting Time
# 0           21.00            10
# 1           13.50             4
# 2           19.75             6
# 3           24.00             9
# 4           29.00            10
# 5           15.35             6
# 6           19.00             7
# 7            9.50             3
# 8           17.90            10
# 9           18.75             9
# 10          19.83             8
# 11          10.75             4
# 12          16.68             7
# 13          11.50             3
# 14          12.03             3
# 15          14.88             4
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
# ii) Display first 5 and last 5 records.
df3.head()
# Out:
#    Delivery Time  Sorting Time
# 0          21.00            10
# 1          13.50             4
# 2          19.75             6
# 3          24.00             9
# 4          29.00            10

# %%
df3.tail()
# Out:
#     Delivery Time  Sorting Time
# 16          13.75             6
# 17          18.11             7
# 18           8.00             2
# 19          17.83             7
# 20          21.50             5

# %%
# iii) Display info and describe the dataset.
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Delivery Time  21 non-null     float64
#  1   Sorting Time   21 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 464.0 bytes

# %%
df3.describe()
# Out:
#        Delivery Time  Sorting Time
# count      21.000000     21.000000
# mean       16.790952      6.190476
# std         5.074901      2.542028
# min         8.000000      2.000000
# 25%        13.500000      4.000000
# 50%        17.830000      6.000000
# 75%        19.750000      8.000000
# max        29.000000     10.000000

# %%
# iv) Find out null values.
df3.isna().sum()
# Out:
# Delivery Time    0
# Sorting Time     0
# dtype: int64

# %%
# v) Plot Various graphs. e.g. barchart, scatterplot, histogram, lineplot, pairplot and all other.
# 1)barchart
#1)barchart
#Delivery Time Sorting Time     
#data
x = df3["Delivery Time"]
y = df3["Sorting Time"]

#set the style

#plot the graph
plt.bar(x,y,color='maroon',width=0.4)

#customize the graph
plt.xlabel("Delivery Time")
plt.ylabel("Sorting Time")
plt.title("Delivery Time with Sorting Time")

#show the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df3.shape
# Out:
# (21, 2)

# %%
# 2)scatterplot
#Delivery Time Sorting Time     
#data
y = df3["Delivery Time"]
x = df3["Sorting Time"]

#set the style

#plot the graph
plt.scatter(x,y)

#customize the graph
plt.xlabel("Sorting Time ")
plt.ylabel("Delivery Time")
plt.title("Sorting Time with Delivery Time ")

#show the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#3)histogram
#data
x = df3["Delivery Time"]

#set the style

#plot the graph
plt.hist(x)

#customize the graph
plt.xlabel("Delivery Time ")
plt.ylabel("Number of Delivery")
plt.title("distribution of Delivery")

#show the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#4)lineplot
#plot the graph
sns.lineplot(x='Delivery Time',y='Sorting Time',data=df3)

#customize the graph
plt.xlabel("Sorting Time ")
plt.ylabel("Delivery Time")
plt.title("Sorting Time with Delivery Time ")

#show the graph
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# 5)pairplot
sns.pairplot(data=df3)

# %%
# vii)  Find out correlation and covariance in the dataset.
df3.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %%
df3.corr()
# Out:
#                Delivery Time  Sorting Time
# Delivery Time       1.000000      0.825997
# Sorting Time        0.825997      1.000000

# %% [markdown]
# # iv) SAT-GPA.csv

# %%
#i) Read the dataset.
df4 = pd.read_csv('SAT-GPA .csv')
df4
# Out:
#      SAT   GPA
# 0   1714  2.40
# 1   1664  2.52
# 2   1760  2.54
# 3   1685  2.74
# 4   1693  2.83
# ..   ...   ...
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81
#
# [84 rows x 2 columns]

# %%
# ii) Display first 5 and last 5 records.
def get_first5(df):
    print("First Fice Rows:\n")
    print(df.head())

# %%
get_first5(df4)
# Out:
# First Fice Rows:
#
#     SAT   GPA
# 0  1714  2.40
# 1  1664  2.52
# 2  1760  2.54
# 3  1685  2.74
# 4  1693  2.83

# %%
def get_last5(df):
    print("Last Five Rows:")
    print(df.tail())

# %%
get_last5(df4)
# Out:
# Last Five Rows:
#      SAT   GPA
# 79  1936  3.71
# 80  1810  3.71
# 81  1987  3.73
# 82  1962  3.76
# 83  2050  3.81

# %%
#iii) Display info and describe the dataset.
def get_info_describe(df):
    print("Information About Dataset:\n")
    print(df.info())
    print("*"*50)
    print("Descibe About Dataset:\n")
    print(df.describe())

# %%
get_info_describe(df4)
# Out:
# Information About Dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   SAT     84 non-null     int64
#  1   GPA     84 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 1.4 KB
# None
# **************************************************
# Descibe About Dataset:
#
#                SAT        GPA
# count    84.000000  84.000000
# mean   1845.273810   3.330238
# std     104.530661   0.271617
# min    1634.000000   2.400000
# 25%    1772.000000   3.190000
# 50%    1846.000000   3.380000
# 75%    1934.000000   3.502500
# max    2050.000000   3.810000

# %%
# iv) Find out null values.
def get_null(df):
    print("Null values:\n")
    print(df.isna().sum())

# %%
get_null(df4)
# Out:
# Null values:
#
# SAT    0
# GPA    0
# dtype: int64

# %%
# v) Plot Various graphs. e.g. barchart, scatterplot, histogram, lineplot, pairplot and all other.

# %%
# 2)barchart
plt.bar()
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Title')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [178], in <cell line: 2>()
#       1 # 2)barchart
# ----> 2 plt.bar(x_values=df4["SAT"],y_values=df4["GPA"])
#       3 plt.xlabel('X-axis Label')
#       4 plt.ylabel('Y-axis Label')
#
# TypeError: bar() missing 2 required positional arguments: 'x' and 'height'

# %%
#1)barchat
plt.plot(x_values=df4["SAT"], y_values=df4["GPA"])
plt.xlabel('X-axis Label')
plt.ylabel('Y-axis Label')
plt.title('Title')
plt.show()

# %%
# vii)  Find out correlation and covariance in the dataset.
def get_corr_cov(df):
    print("Co-relation:\n")
    print(df.corr())
    print("*"*50)
    print("Covariance:\n")
    print(df.cov())

# %%
get_corr_cov(df4)
# Out:
# Co-relation:
#
#           SAT       GPA
# SAT  1.000000  0.637184
# GPA  0.637184  1.000000
# **************************************************
# Covariance:
#
#               SAT        GPA
# SAT  10926.659065  18.091139
# GPA     18.091139   0.073776

# %% [markdown]
# # v) TvMarketing.csv

# %%
# i) Read the dataset.
df5 = pd.read_csv("TvMarketing.csv")
df5.sample()
# Out:
#       TV  Sales
# 60  53.5    8.1

# %%
# ii) Display first 5 and last 5 records.
get_first5(df5)
# Out:
# First Fice Rows:
#
#       TV  Sales
# 0  230.1   22.1
# 1   44.5   10.4
# 2   17.2    9.3
# 3  151.5   18.5
# 4  180.8   12.9

# %%
get_last5(df5)
# Out:
# Last Five Rows:
#         TV  Sales
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4

# %%
# iii) Display info and describe the dataset.
get_info_describe(df5)
# Out:
# Information About Dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TV      200 non-null    float64
#  1   Sales   200 non-null    float64
# dtypes: float64(2)
# memory usage: 3.2 KB
# None
# **************************************************
# Descibe About Dataset:
#
#                TV       Sales
# count  200.000000  200.000000
# mean   147.042500   14.022500
# std     85.854236    5.217457
# min      0.700000    1.600000
# 25%     74.375000   10.375000
# 50%    149.750000   12.900000
# 75%    218.825000   17.400000
# max    296.400000   27.000000

# %%
# iv) Find out null values.
get_null(df5)
# Out:
# Null values:
#
# TV       0
# Sales    0
# dtype: int64

# %%
# v) Plot Various graphs. e.g. barchart, scatterplot, histogram, lineplot, pairplot and all other.
plt.bar(x=df5["Sales"],height=0.5)
# Out:
# <BarContainer object of 200 artists>

# %%
# vii)  Find out correlation and covariance in the dataset.
get_corr_cov(df5)
# Out:
# Co-relation:
#
#              TV     Sales
# TV     1.000000  0.782224
# Sales  0.782224  1.000000
# **************************************************
# Covariance:
#
#                 TV       Sales
# TV     7370.949893  350.390195
# Sales   350.390195   27.221853

# %% [markdown]
# # vi) NewspaperData.csv

# %%
def get_information(filename):
    # i) Read the dataset.
    global df
    df = pd.read_csv(filename)
    # ii) Display first 5 and last 5 records.
    print("*"*50)
    print("First Five Rows:\n")
    print(df.head())
    print("*"*50)
    print("Last Five Rows:\n")
    print(df.tail())
    print("*"*50)
    # iii) Display info and describe the dataset.
    print("Information About Dataset:\n")
    print(df.info())
    print("*"*50)
    print("Desription About Dataset:\n")
    print(df.describe())
    print("*"*50)
    # iv) Find out null values.
    print("Null Values:\n")
    print(df.isna().sum())
    print("*"*50)
    # v) Plot Various graphs. e.g. barchart, scatterplot, histogram, lineplot, pairplot and all other.
    # vii)  Find out correlation and covariance in the dataset.
    print("Correlation Among The Data:\n")
    print(df.corr())
    print("*"*50)
    print("Covariance Of The Dataset\n")
    print(df.cov())
    print("*"*50)

# %%
get_information('NewspaperData.csv')
# Out:
# **************************************************
# First Five Rows:
#
#             Newspaper    daily   sunday
# 0       Baltimore Sun  391.952  488.506
# 1        Boston Globe  516.981  798.298
# 2       Boston Herald  355.628  235.084
# 3  Charlotte Observer  238.555  299.451
# 4   Chicago Sun Times  537.780  559.093
# **************************************************
# Last Five Rows:
#
#                   Newspaper    daily    sunday
# 29  San Francisco Chronicle  570.364   704.322
# 30  St. Louis Post-Dispatch  391.286   585.681
# 31   St. Paul Pioneer Press  201.860   267.781
# 32            Tampa Tribune  321.626   408.343
# 33          Washington Post  838.902  1165.567
# **************************************************
# Information About Dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
# ...

# %%
df.columns
# Out:
# Index(['Newspaper', 'daily', 'sunday'], dtype='object')

# %%
newspaper = df["Newspaper"].unique()
penguin_means = {
    'Dai (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
sns.barplot(x='Newspaper',y='daily',data=df)
# Out:
# <AxesSubplot: xlabel='Newspaper', ylabel='daily'>

# %%
df.plot.bar(color=['0.5','0.6'])
# Out:
# <AxesSubplot: >

# %%
# df=df.reset_index()
df=df.set_index('Newspaper')
df
# Out:
#                                 level_0  index     daily    sunday
# Newspaper
# Baltimore Sun                         0      0   391.952   488.506
# Boston Globe                          1      1   516.981   798.298
# Boston Herald                         2      2   355.628   235.084
# Charlotte Observer                    3      3   238.555   299.451
# Chicago Sun Times                     4      4   537.780   559.093
# Chicago Tribune                       5      5   733.775  1133.249
# Cincinnati Enquirer                   6      6   198.832   348.744
# Denver Post                           7      7   252.624   417.779
# Des Moines Register                   8      8   206.204   344.522
# Hartford Courant                      9      9   231.177   323.084
# Houston Chronicle                    10     10   449.755   620.752
# Kansas City Star                     11     11   288.571   423.305
# Los Angeles Daily  News              12     12   185.736   202.614
# ...

# %%
df=df.iloc[:,2:]
df
# Out:
#                                    daily    sunday
# Newspaper
# Baltimore Sun                    391.952   488.506
# Boston Globe                     516.981   798.298
# Boston Herald                    355.628   235.084
# Charlotte Observer               238.555   299.451
# Chicago Sun Times                537.780   559.093
# Chicago Tribune                  733.775  1133.249
# Cincinnati Enquirer              198.832   348.744
# Denver Post                      252.624   417.779
# Des Moines Register              206.204   344.522
# Hartford Courant                 231.177   323.084
# Houston Chronicle                449.755   620.752
# Kansas City Star                 288.571   423.305
# Los Angeles Daily  News          185.736   202.614
# Los Angeles Times               1164.388  1531.527
# Miami Herald                     444.581   553.479
# Minneapolis Star Tribune         412.871   685.975
# New Orleans Times-Picayune       272.280   324.241
# ...

# %%
plt.figure(figsize=(500, 10))
df.plot.bar(color=['green','red'])
plt.show()

# %% [markdown]
# # vii) claimants.csv

# %%
get_information('claimants.csv')
# Out:
# **************************************************
# First Five Rows:
#
#    ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0         0     0.0       1.0       0.0    50.0  34.940
# 1         1     1.0       0.0       0.0    18.0   0.891
# 2         1     0.0       1.0       0.0     5.0   0.330
# 3         0     0.0       1.0       1.0    31.0   0.037
# 4         1     0.0       1.0       0.0    30.0   0.038
# **************************************************
# Last Five Rows:
#
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE   LOSS
# 1335         1     0.0       1.0       0.0     NaN  0.576
# 1336         0     1.0       1.0       0.0    46.0  3.705
# 1337         1     1.0       1.0       0.0    39.0  0.099
# 1338         0     1.0       0.0       0.0     8.0  3.177
# 1339         1     1.0       1.0       0.0    30.0  0.688
# **************************************************
# Information About Dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
sns.scatterplot(x='LOSS',y='SEATBELT',data=df)
# Out:
# <AxesSubplot: xlabel='LOSS', ylabel='SEATBELT'>

# %%
df.corr()
# Out:
#           ATTORNEY    CLMSEX  CLMINSUR  SEATBELT    CLMAGE      LOSS
# ATTORNEY  1.000000  0.079674  0.079439 -0.057189  0.010680 -0.219715
# CLMSEX    0.079674  1.000000  0.066413 -0.015024 -0.023195 -0.027611
# CLMINSUR  0.079439  0.066413  1.000000  0.021154  0.049493  0.005821
# SEATBELT -0.057189 -0.015024  0.021154  1.000000 -0.027992  0.111189
# CLMAGE    0.010680 -0.023195  0.049493 -0.027992  1.000000  0.064612
# LOSS     -0.219715 -0.027611  0.005821  0.111189  0.064612  1.000000

# %% [markdown]
# # viii) framingham.csv

# %%
get_information('framingham.csv')
# Out:
# **************************************************
# First Five Rows:
#
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# ...

# %%
df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %%
df["cigsPerDay"].unique()
# Out:
# array([ 0., 20., 30., 23., 15.,  9., 10.,  5., 35., 43.,  1., 40.,  3.,
#         2., nan, 12.,  4., 18., 25., 60., 14., 45.,  8., 50., 13., 11.,
#         7.,  6., 38., 29., 17., 16., 19., 70.])

# %%
x_axis = df["male"]
y_axis = df["cigsPerDay"]
sns.barplot(x=x_axis,y=y_axis)
plt.show()

# %% [markdown]
# # ix) crime_data.csv

# %%
df.rename(columns={"Unnamed: 0":"City"},inplace=True)

# %%
df
# Out:
#               City  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# ...

# %%
df.columns
# Out:
# Index(['City', 'Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')

# %%
df["Murder"].unique()
# Out:
# array([13.2, 10. ,  8.1,  8.8,  9. ,  7.9,  3.3,  5.9, 15.4, 17.4,  5.3,
#         2.6, 10.4,  7.2,  2.2,  6. ,  9.7,  2.1, 11.3,  4.4, 12.1,  2.7,
#        16.1,  4.3, 12.2,  7.4, 11.4, 11.1, 13. ,  0.8,  7.3,  6.6,  4.9,
#         6.3,  3.4, 14.4,  3.8, 12.7,  3.2,  8.5,  4. ,  5.7,  6.8])

# %%
get_information('crime_data.csv')
# Out:
# **************************************************
# First Five Rows:
#
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6
# **************************************************
# Last Five Rows:
#
#        Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 45       Virginia     8.5      156        63  20.7
# 46     Washington     4.0      145        73  26.2
# 47  West Virginia     5.7       81        39   9.3
# 48      Wisconsin     2.6       53        66  10.8
# 49        Wyoming     6.8      161        60  15.6
# **************************************************
# Information About Dataset:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ...

# %% [markdown]
# # x) Universities.csv

# %%
get_information('Universities.csv')
# Out:
# **************************************************
# First Five Rows:
#
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90
# **************************************************
# Last Five Rows:
#
#           Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 20   UMichigan  1180     65      68       16     15470        85
# 21       UPenn  1285     80      36       11     27553        90
# 22         UVA  1225     77      44       14     13349        92
# 23  UWisconsin  1085     40      69       15     11857        71
# 24        Yale  1375     95      19       11     43514        96
# **************************************************
# ...

# %% [markdown]
# # xi) wine.csv

# %%
get_information('wine.csv')
# Out:
# **************************************************
# First Five Rows:
#
#    Type  Alcohol  Malic   Ash  Alcalinity  Magnesium  Phenols  Flavanoids  \
# 0     1    14.23   1.71  2.43        15.6        127     2.80        3.06
# 1     1    13.20   1.78  2.14        11.2        100     2.65        2.76
# 2     1    13.16   2.36  2.67        18.6        101     2.80        3.24
# 3     1    14.37   1.95  2.50        16.8        113     3.85        3.49
# 4     1    13.24   2.59  2.87        21.0        118     2.80        2.69
#
#    Nonflavanoids  Proanthocyanins  Color   Hue  Dilution  Proline
# 0           0.28             2.29   5.64  1.04      3.92     1065
# 1           0.26             1.28   4.38  1.05      3.40     1050
# 2           0.30             2.81   5.68  1.03      3.17     1185
# 3           0.24             2.18   7.80  0.86      3.45     1480
# 4           0.39             1.82   4.32  1.04      2.93      735
# **************************************************
# ...

# %% [markdown]
# # xii) glass

# %%
get_information('glass.csv')
# Out:
# **************************************************
# First Five Rows:
#
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1
# **************************************************
# Last Five Rows:
#
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7
# ...

# %%
df12 = pd.read_csv('glass.csv')
df12.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
#1.lineplot
#data
x = df12["RI"]
y = df12["Ca"]
#set the type
#plot the graph
plt.plot(x,y)
#customize the graph
plt.xlabel('RI')
plt.ylabel('Ca')
plt.title('Lineplot RI And Ca')
#save the graph
#show the graph
plt.show()

# %%
#barchart
#data
x = df12["Type"]
y = df12["Ca"]
#set the type
#plot the graph
plt.boxplot(x)
#customize the graph
#save the graph
#show the graph
plt.show()

# %%
#3.histogram
plt.hist(x)
# Out:
# (array([70., 76.,  0., 17.,  0.,  0., 13.,  0.,  9., 29.]),
#  array([1. , 1.6, 2.2, 2.8, 3.4, 4. , 4.6, 5.2, 5.8, 6.4, 7. ]),
#  <BarContainer object of 10 artists>)

# %%
#data
#set the type
#plot the graph
#customize the graph
#save the graph
#show the graph

# %%
Consider each of following datasets and do below operations.
i) Read the dataset.
ii) Display first 5 and last 5 records. 
iii) Display info and describe the dataset.
iv) Find out null values.
v) Plot Various graphs. e.g. barchart, scatterplot, histogram, lineplot, pairplot and all other.
vii)  Find out correlation and covariance in the dataset.
