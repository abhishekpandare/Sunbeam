# %%
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder,OrdinalEncoder,LabelEncoder 
from sklearn.model_selection import train_test_split

# %% [markdown]
# # Dataset-1

# %%
df = pd.read_csv('ToyotaCorolla.csv',encoding='ISO-8859-1')
df.head()
# Out:
#    Id                                           Model  Price  Age_08_04  \
# 0   1   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13500         23
# 1   2   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13750         23
# 2   3   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  13950         24
# 3   4   TOYOTA Corolla 2.0 D4D HATCHB TERRA 2/3-Doors  14950         26
# 4   5     TOYOTA Corolla 2.0 D4D HATCHB SOL 2/3-Doors  13750         30
#
#    Mfg_Month  Mfg_Year     KM Fuel_Type  HP  Met_Color  ... Central_Lock  \
# 0         10      2002  46986    Diesel  90          1  ...            1
# 1         10      2002  72937    Diesel  90          1  ...            1
# 2          9      2002  41711    Diesel  90          1  ...            0
# 3          7      2002  48000    Diesel  90          0  ...            0
# 4          3      2002  38500    Diesel  90          0  ...            1
#
#    Powered_Windows  Power_Steering  Radio  Mistlamps  Sport_Model  \
# ...

# %%
df.shape
# Out:
# (1436, 38)

# %%
df["Model"].nunique()
# Out:
# 372

# %%
df = df.drop('Id',axis=1)

# %%
model = df[["Model"]]
# Out:
# pandas.core.frame.DataFrame

# %%
model_oe = OrdinalEncoder()
model_oe = model_oe.fit(model)
model_num = model_oe.transform(model)
model_num
# Out:
# array([[257.],
#        [257.],
#        [365.],
#        ...,
#        [  8.],
#        [  8.],
#        [163.]])

# %%
df["Model Num"] = model_num

# %%
df["Model Num"].nunique()
# Out:
# 372

# %%
df.columns
# Out:
# Index(['Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Color', 'Automatic', 'cc', 'Doors',
#        'Cylinders', 'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee',
#        'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2',
#        'Airco', 'Automatic_airco', 'Boardcomputer', 'CD_Player',
#        'Central_Lock', 'Powered_Windows', 'Power_Steering', 'Radio',
#        'Mistlamps', 'Sport_Model', 'Backseat_Divider', 'Metallic_Rim',
#        'Radio_cassette', 'Tow_Bar', 'Model Num'],
#       dtype='object')

# %%
#fuel-type
df["Fuel_Type"].nunique()
# Out:
# 3

# %%
df["Fuel_Type"].value_counts().to_dict()
# Out:
# {'Petrol': 1264, 'Diesel': 155, 'CNG': 17}

# %%
df["Fuel_Type"] = df["Fuel_Type"].replace({'Petrol': 0, 'Diesel': 1, 'CNG': 1})

# %%
df['Color'].nunique()
# Out:
# 10

# %%
color_num = OrdinalEncoder()
color_num = color_num.fit(df[["Color"]])
color_num = color_num.transform(df[["Color"]])
color_num
# Out:
# array([[2.],
#        [6.],
#        [2.],
#        ...,
#        [2.],
#        [4.],
#        [3.]])

# %%
df["Color Num"] = color_num

# %%
df.drop('Model',axis=1,inplace=True)
df
# Out:
#       Price  Age_08_04  Mfg_Month  Mfg_Year     KM  Fuel_Type   HP  Met_Color  \
# 0     13500         23         10      2002  46986          1   90          1
# 1     13750         23         10      2002  72937          1   90          1
# 2     13950         24          9      2002  41711          1   90          1
# 3     14950         26          7      2002  48000          1   90          0
# 4     13750         30          3      2002  38500          1   90          0
# ...     ...        ...        ...       ...    ...        ...  ...        ...
# 1431   7500         69         12      1998  20544          0   86          1
# 1432  10845         72          9      1998  19000          0   86          0
# 1433   8500         71         10      1998  17016          0   86          0
# 1434   7250         70         11      1998  16916          0   86          1
# 1435   6950         76          5      1998      1          0  110          0
#
# ...

# %%
df.drop('Color',axis=1,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 37 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Price             1436 non-null   int64
#  1   Age_08_04         1436 non-null   int64
#  2   Mfg_Month         1436 non-null   int64
#  3   Mfg_Year          1436 non-null   int64
#  4   KM                1436 non-null   int64
#  5   Fuel_Type         1436 non-null   int64
#  6   HP                1436 non-null   int64
#  7   Met_Color         1436 non-null   int64
#  8   Automatic         1436 non-null   int64
#  9   cc                1436 non-null   int64
#  10  Doors             1436 non-null   int64
#  11  Cylinders         1436 non-null   int64
#  12  Gears             1436 non-null   int64
#  13  Quarterly_Tax     1436 non-null   int64
#  14  Weight            1436 non-null   int64
#  15  Mfr_Guarantee     1436 non-null   int64
# ...

# %%
x = df.drop('Price',axis=1)
y = df["Price"]

# %%
len(x)
# Out:
# 1436

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=45)

# %%
len(x_train)
# Out:
# 1148

# %%
len(x_test)
# Out:
# 288

# %%
df.corr()
# Out:
#                      Price  Age_08_04  Mfg_Month  Mfg_Year        KM  \
# Price             1.000000  -0.876590  -0.018138  0.885159 -0.569960
# Age_08_04        -0.876590   1.000000  -0.123255 -0.983661  0.505672
# Mfg_Month        -0.018138  -0.123255   1.000000 -0.057416 -0.020630
# Mfg_Year          0.885159  -0.983661  -0.057416  1.000000 -0.504974
# KM               -0.569960   0.505672  -0.020630 -0.504974  1.000000
# Fuel_Type         0.038516  -0.092611   0.049646  0.084162  0.433160
# HP                0.314990  -0.156622  -0.039312  0.164697 -0.333538
# Met_Color         0.108905  -0.108150   0.030266  0.103310 -0.080503
# Automatic         0.033081   0.031717   0.009146 -0.033567 -0.081854
# cc                0.126389  -0.098084   0.037387  0.091892  0.102683
# Doors             0.185326  -0.148359  -0.012069  0.151442 -0.036197
# Cylinders              NaN        NaN        NaN       NaN       NaN
# Gears             0.063104  -0.005364  -0.013063  0.007766  0.015023
# ...

# %%
df.isna().sum()
# Out:
# Price               0
# Age_08_04           0
# Mfg_Month           0
# Mfg_Year            0
# KM                  0
# Fuel_Type           0
# HP                  0
# Met_Color           0
# Automatic           0
# cc                  0
# Doors               0
# Cylinders           0
# Gears               0
# Quarterly_Tax       0
# Weight              0
# Mfr_Guarantee       0
# BOVAG_Guarantee     0
# Guarantee_Period    0
# ABS                 0
# Airbag_1            0
# Airbag_2            0
# Airco               0
# Automatic_airco     0
# Boardcomputer       0
# CD_Player           0
# Central_Lock        0
# Powered_Windows     0
# Power_Steering      0
# Radio               0
# Mistlamps           0
# Sport_Model         0
# Backseat_Divider    0
# Metallic_Rim        0
# Radio_cassette      0
# Tow_Bar             0
# Model Num           0
# Color Num           0
# dtype: int64

# %%
df["Cylinders"]
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 1431    4
# 1432    4
# 1433    4
# 1434    4
# 1435    4
# Name: Cylinders, Length: 1436, dtype: int64

# %%
df = pd.read_csv('food_coded.csv')
df
# Out:
#        GPA  Gender  breakfast  calories_chicken  calories_day  calories_scone  \
# 0      2.4       2          1               430           NaN           315.0
# 1    3.654       1          1               610           3.0           420.0
# 2      3.3       1          1               720           4.0           420.0
# 3      3.2       1          1               430           3.0           420.0
# 4      3.5       1          1               720           2.0           420.0
# ..     ...     ...        ...               ...           ...             ...
# 120    3.5       1          1               610           4.0           420.0
# 121      3       1          1               265           2.0           315.0
# 122  3.882       1          1               720           NaN           420.0
# 123      3       2          1               720           4.0           420.0
# 124    3.9       1          1               430           NaN           315.0
#
# ...

# %%
df['GPA'].isna().sum()
# Out:
# 2

# %%
df["GPA"].replace({'Personal': np.nan},inplace=True)

# %%
df['GPA'].value_counts()
# Out:
# 3.5          13
# 3            11
# 3.7          10
# 3.2          10
# 3.3           9
# 3.4           9
# 3.6           7
# 3.9           7
# 3.8           6
# 2.8           5
# 4             4
# 3.1           3
# 2.9           2
# 2.6           2
# 3.83          2
# 3.79          1
# 2.71          1
# 3.73          1
# 2.4           1
# 3.92          1
# 3.68          1
# 3.75          1
# 3.77          1
# 3.63          1
# 3.67          1
# 3.65          1
# Personal      1
# 3.35          1
# 3.292         1
# 3.605         1
# 3.89          1
# 3.654         1
# 3.87          1
# 2.2           1
# 3.904         1
# 2.25          1
# 3.882         1
# Name: GPA, dtype: int64

# %%
df.GPA.iloc[61] = np.nan
# Out:
# C:\Users\ABHI\AppData\Local\Temp\ipykernel_5236\4034860673.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.GPA.iloc[61] = np.nan

# %%
df['GPA'].unique()
# Out:
# array(['2.4', '3.654', '3.3', '3.2', '3.5', '2.25', '3.8', '3.904', '3.4',
#        '3.6', '3.1', nan, '4', '2.2', '3.87', '3.7', '3.9', '2.8', '3',
#        '3.65', '3.89', '2.9', '3.605', '3.83', '3.292', '3.35', '2.6',
#        '3.67', '3.73', 3.79, '2.71', '3.68', '3.75', '3.92', '3.77',
#        '3.63', '3.882'], dtype=object)

# %%
df['GPA'] = df['GPA'].astype(float)

# %%
x = df["GPA"].mean()
x
# Out:
# 3.4186528925619832

# %%
df['GPA'].fillna(x,inplace=True)

# %%
df["calories_day"].unique()
# Out:
# array([nan,  3.,  4.,  2.])

# %%
df["calories_day"].mean()
# Out:
# 3.0283018867924527

# %%
x = df["calories_day"].mode()
# Out:
# 0    3.0
# Name: calories_day, dtype: float64

# %%
df["calories_day"].median()
# Out:
# 3.0

# %%
df["calories_day"].fillna(x,inplace=True)

# %%
df["comfort_food"].nunique()
# Out:
# 124

# %%
df["comfort_food"].fillna(method="ffill",inplace=True)

# %%
df["comfort_food"].mode()
# Out:
# 0    Chips, ice cream
# Name: comfort_food, dtype: object

# %%
df["comfort_food"].isna().sum()
# Out:
# 0

# %%
df["comfort_food_reasons"].isna().sum()
# Out:
# 1

# %%
df["comfort_food_reasons"].nunique()
# Out:
# 107

# %%
x = df["comfort_food_reasons"].mode()
# Out:
# 0    boredom
# Name: comfort_food_reasons, dtype: object

# %%
df["comfort_food_reasons"].fillna(x,inplace=True)

# %%
df["comfort_food_reasons"].unique()
# Out:
# array(['we dont have comfort ', 'Stress, bored, anger', 'stress, sadness',
#        'Boredom', 'Stress, boredom, cravings ',
#        "None, i don't eat comfort food. I just eat when i'm hungry.",
#        'stress, boredom',
#        'I eat comfort food when im stressed out from school(finals week), when I`m sad, or when i am dealing with personal family issues.',
#        'Boredom ', 'Stress, anger and sadness ',
#        'sadness, stress, cold weather',
#        'Sadness, boredom, late night snack ',
#        'stress,  boredom, special occasions',
#        'Friends, environment and boredom', 'boredom', 'Stress ',
#        "I usually only eat comfort food when I'm bored, if i am doing something, i can go for hours without eating ",
#        'Sadness, stress', 'boredom, sadness, hungry',
#        'happiness, satisfaction', 'Mostly boredom',
#        'sadness, depression ', 'Stress and boredom ',
#        'A long day, not feeling well, winter ', 'Boredom, lazyniss ',
# ...

# %%
df["calories_scone"].isna().sum()
# Out:
# 1

# %%
x = df["calories_scone"].median()

# %%
df["calories_scone"].mode()
# Out:
# 0    420.0
# Name: calories_scone, dtype: float64

# %%
df["calories_scone"].mean()
# Out:
# 505.241935483871

# %%
df["calories_scone"].fillna(x,inplace=True)

# %%
df["calories_scone"].isna().sum()
# Out:
# 0

# %%
df["comfort_food"].dtype
# Out:
# dtype('O')

# %%
df[""]

# %%
from sklearn.preprocessing import LabelEncoder
comfort_food = LabelEncoder()
df["comfort_food"] = comfort_food.fit_transform(df["comfort_food"])

# %%
df["comfort_food_reasons"].unique()
# Out:
# array(['we dont have comfort ', 'Stress, bored, anger', 'stress, sadness',
#        'Boredom', 'Stress, boredom, cravings ',
#        "None, i don't eat comfort food. I just eat when i'm hungry.",
#        'stress, boredom',
#        'I eat comfort food when im stressed out from school(finals week), when I`m sad, or when i am dealing with personal family issues.',
#        'Boredom ', 'Stress, anger and sadness ',
#        'sadness, stress, cold weather',
#        'Sadness, boredom, late night snack ',
#        'stress,  boredom, special occasions',
#        'Friends, environment and boredom', 'boredom', 'Stress ',
#        "I usually only eat comfort food when I'm bored, if i am doing something, i can go for hours without eating ",
#        'Sadness, stress', 'boredom, sadness, hungry',
#        'happiness, satisfaction', 'Mostly boredom',
#        'sadness, depression ', 'Stress and boredom ',
#        'A long day, not feeling well, winter ', 'Boredom, lazyniss ',
# ...

# %%
df["comfort_food_reasons"].isna().sum()
# Out:
# 0

# %%
df["comfort_food_reasons"].value_counts()
# Out:
# boredom                              7
# sadness                              3
# Boredom                              3
# Boredom                              3
# boredom, sadness                     2
#                                     ..
# Usually if I'm sad or depressed.     1
# No reasons                           1
# boredom, stress                      1
# Stress                               1
# hormones, Premenstrual syndrome.     1
# Name: comfort_food_reasons, Length: 108, dtype: int64

# %%
df["comfort_food_reasons"] = df["comfort_food_reasons"].astype(str)

# %%
from sklearn.preprocessing import LabelEncoder
comfort_food_reasons = LabelEncoder()
df["comfort_food_reasons"] = comfort_food_reasons.fit_transform(df[["comfort_food_reasons"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df["comfort_food_reasons_coded"].unique()
# Out:
# array([ 9.,  1.,  2.,  4.,  3.,  7.,  6.,  5.,  8., nan])

# %%
df["comfort_food_reasons_coded"].mean()
# Out:
# 2.69811320754717

# %%
df["comfort_food_reasons_coded"].median()
# Out:
# 2.0

# %%
x = df["comfort_food_reasons_coded"].mode()
# Out:
# 0    2.0
# Name: comfort_food_reasons_coded, dtype: float64

# %%
df["comfort_food_reasons_coded"].fillna(x,inplace=True)

# %%
df["cuisine"].unique()
# Out:
# array([nan,  1.,  3.,  2.,  6.,  4.,  5.])

# %%
def mmm(col):
    mode = df[f'{col}'].mode()
    print(mode)
    median = df[f'{col}'].median()
    print(median)
    mean = df[f'{col}'].mean()
    print(mean)

# %%
mmm('cuisine')
# Out:
# 0    1.0
# Name: cuisine, dtype: float64
# 1.0
# 1.3888888888888888

# %%
df["cuisine"].fillna(df["cuisine"].median(),inplace=True)

# %%
df["diet_current"].isna().sum()
# Out:
# 1

# %%
df["diet_current"].nunique()
# Out:
# 124

# %%
df["diet_current"].fillna(method='ffill',inplace=True)

# %%
from sklearn.preprocessing import OrdinalEncoder
diet_current = OrdinalEncoder()
df["diet_current"] = diet_current.fit_transform(df[["diet_current"]])

# %%
df["drink"].isna().sum()
# Out:
# 2

# %%
df["drink"].unique()
# Out:
# array([ 1.,  2., nan])

# %%
df["drink"].fillna(df["drink"].mode(),inplace=True)

# %%
df["eating_changes"].fillna(method='ffill',inplace=True)

# %%
df['eating_changes'].nunique()
# Out:
# 121

# %%
df["eating_changes"].unique()
# Out:
# array(['eat faster ', 'I eat out more than usual. ',
#        'sometimes choosing to eat fast food instead of cooking simply for convenience',
#        'Accepting cheap and premade/store bought foods',
#        'I have eaten generally the same foods but I do find myself eating the same food frequently due to what I have found I like from egan and the laker. ',
#        'Eating rice everyday. Eating less homemade food.',
#        "I started eating a lot less and healthier because I wasn't playing sports year round anymore.",
#        'Freshmen year i ate very unhealthy, but now it is much healthier because of self control.',
#        'I snack less',
#        "I cook a lot of my own foods back at home so not being able to cook my own healthy choices. I eat more carbs than normal when I'm at college due to the choices given in the cafe. ",
#        'Nun ', 'Less meat. ',
#        'I have been eating a lot more salads and soups.',
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["eating_changes"] = le.fit_transform(df[["eating_changes"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df["cook"].unique()
# Out:
# array([ 2.,  3.,  1.,  5.,  4., nan])

# %%
mmm('cook')
# Out:
# 0    3.0
# Name: cook, dtype: float64
# 3.0
# 2.7868852459016393

# %%
df["cook"].fillna(df["cook"].mean(),inplace=True)

# %%
df["drink"].unique()
# Out:
# array([ 1.,  2., nan])

# %%
mmm('drink')
# Out:
# 0    2.0
# Name: drink, dtype: float64
# 2.0
# 1.5609756097560976

# %%
df["drink"].fillna(df["drink"].mean(),inplace=True)

# %%
df["employment"].unique()
# Out:
# array([ 3.,  2.,  1., nan])

# %%
mmm('employment')
# Out:
# 0    2.0
# Name: employment, dtype: float64
# 2.0
# 2.4482758620689653

# %%
df["employment"]= df["employment"].fillna(df["employment"].mean())

# %%
df["exercise"].unique()
# Out:
# array([ 1.,  2.,  3., nan])

# %%
mmm("exercise")
# Out:
# 0    1.0
# Name: exercise, dtype: float64
# 1.0
# 1.5892857142857142

# %%
df["exercise"].fillna(df["exercise"].median(),inplace=True)

# %%
df["father_education"].unique()
# Out:
# array([ 5.,  2.,  4.,  1.,  3., nan])

# %%
mmm("father_education")
# Out:
# 0    4.0
# Name: father_education, dtype: float64
# 4.0
# 3.4838709677419355

# %%
df["father_education"].isna().sum()
# Out:
# 1

# %%
df["father_education"].fillna(df["father_education"].median(),inplace=True)

# %%
df["father_profession"].unique()
# Out:
# array(['profesor ', 'Self employed ', 'owns business', 'Mechanic ', 'IT',
#        'Taxi Driver', 'Assembler ', 'Business guy',
#        'High School Principal', 'commissioner of erie county ', 'Idk',
#        'Home Marker ', 'Shirt designer ', 'business owner',
#        'Commidity trader ', 'Hockey Coach', 'Construction ',
#        'self employed construction ', 'Engineer', 'architect', 'CFO',
#        'European logistics director ', 'accountant ',
#        'Commercial Real Estate', 'Manager at Pepsi', 'VP of ',
#        'Beverage and Food Sales', 'Dentist ', 'Electrical Engineer',
#        'Radio Telecommunications Manager', nan, 'deceased', 'Lawyer',
#        'landscaping ', 'Vice President of a company',
#        'Owns his own promotional company ', 'Optometrist ',
#        'Biohemical Waste Elimination', 'Corporate Manager ',
#        'Small business owner ', 'Welder', 'Design Engineer', 'Unknown ',
#        'Banker', 'subcontractor ', 'small business owner ',
# ...

# %%
df["father_profession"].nunique()
# Out:
# 114

# %%
df["father_profession"].mode()
# Out:
# 0         Business Owner
# 1          Construction
# 2               Dentist
# 3    Electrical Engineer
# 4                     IT
# 5                 Lawyer
# 6                Teacher
# 7         business owner
# Name: father_profession, dtype: object

# %%
df["father_profession"] =df["father_profession"].fillna("IT")

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
df["father_profession"] = oe.fit_transform(df[["father_profession"]])

# %%
df["fav_cuisine"].unique()
# Out:
# array(['Arabic cuisine', 'Italian', 'italian', 'Turkish ', 'Italian ',
#        'African', 'Thai', 'Anything american style.', 'Seafood',
#        'Orange chicken and chow mani noodles ', 'Chinese ',
#        'italian food', 'Jamaican ', 'American or Italian ', 'Chicken ',
#        'Mexican', 'Indian', 'italian ', 'Asian ', 'Chinese',
#        "don't have one", 'Italian food ', 'Mexican ', 'Italian/German',
#        'Indian food - samosas are amazing', 'mexican', 'Spanish',
#        'French', 'American or Italian', 'Italian or Chinese ', 'chinese',
#        'Thai food', 'Greek', 'American', 'All ', 'Sub sandwhiches',
#        'Wraps ', "Chinese cuisine (General Tso's)", 'American ', 'Lean',
#        nan, 'american ', 'Japanese', 'Any type of Colombian cuisine',
#        'Mexican cuisine', 'Asian', 'Chinese food', 'mac and cheese',
#        'Authentic Chinese and Vietnamese food ', 'italian and chinese',
#        'Barbecue ', 'lebanese or greek', 'sushi', 'Indian food', 'Nepali',
# ...

# %%
df["fav_cuisine"].nunique()
# Out:
# 60

# %%
df["fav_cuisine"].isna().sum()
# Out:
# 2

# %%
df["fav_cuisine"] = df["fav_cuisine"].fillna(method='ffill')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["fav_cuisine"] = le.fit_transform(df[["fav_cuisine"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df["fav_food"].unique()
# Out:
# array([ 1.,  3.,  2., nan])

# %%
df["fav_food"].nunique()
# Out:
# 3

# %%
df["fav_food"] = df["fav_food"].fillna(df["fav_food"].median())

# %%
df["food_childhood"].unique()
# Out:
# array(['rice  and chicken ',
#        'chicken and biscuits, beef soup, baked beans',
#        'mac and cheese, pizza, tacos', 'Beef stroganoff, tacos, pizza',
#        'Pasta, chicken tender, pizza ', 'Fries, plaintain & fried fish',
#        'grilled chicken, hamburgers',
#        'chicken, cheesey potatoes, and hot dogs', 'Shrimp, spaghetti',
#        'Pasta, Eggs, Pancakes ', 'Chicken', 'Scalloped potatoes and ham ',
#        'Pizza, chicken wings, and corn on the cob ',
#        'steak, lasagna, crab', 'Pizza', 'pizza',
#        'Curry, Stew Chicken and Saltfish',
#        'chicken fingers, steak, mac and cheese', 'manacotti',
#        'pizza, chicken fingers', 'Pasta', 'pasta', 'Chicken Nuggets',
#        'Spaghetti ', 'Chicken parm, beef stroganof, tacos',
#        'Chicken Parm, Pizza ', 'Steak',
#        'Deer Steak, Buttered Pasta, Garlic Pasta',
#        'Crab legs, Mushroom soup, homemade rolls',
#        'french fries, waffles, chocolate', 'chicken and biscuits',
# ...

# %%
df["food_childhood"].nunique()
# Out:
# 114

# %%
df["food_childhood"] = df["food_childhood"].fillna(method='ffill')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["food_childhood"] = le.fit_transform(df[["food_childhood"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df["healthy_meal"].unique()
# Out:
# array(['looks not oily ',
#        'Grains, Veggies, (more of grains and veggies), small protein and fruit with dairy ',
#        'usually includes natural ingredients; nonprocessed food',
#        'Fresh fruits& vegetables, organic meats ',
#        'A lean protein such as grilled chicken, green vegetables and  brown rice or other whole grain ',
#        'Requires veggies, fruits and a cooked meal. ',
#        'Protein, vegetables, fruit, and some carbs',
#        'A healthy meal has a piece of meat followed by a lot of fruit and veggies',
#        'Colorful', 'Chicken and rice with a side of veggies. ',
#        'Chicken, and veggies ',
#        'lean protein, veggies, fruit, complex carbs',
#        'A salad with a reasonable amount of dressing and a meat.',
#        'Lots of vegetabls with some grains like rice. Also has lean meat such as fish or chicken.',
#        'Green and not greasy', 'chicken, veggies, rice',
# ...

# %%
df["healthy_meal"] = df1["healthy_meal"]

# %%
df["healthy_meal"].isna().sum()
# Out:
# 1

# %%
df["healthy_meal"] =df["healthy_meal"].fillna(method='bfill')

# %%
df['healthy_meal'].isna().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import OrdinalEncoder
oe = OrdinalEncoder()
df["healthy_meal"] = oe.fit_transform(df[["healthy_meal"]])

# %%
df["ideal_diet"].unique()
# Out:
# array(['being healthy ',
#        'Try to eat 5-6 small meals a day. While trying to properly distribute carbs, protein, fruits, veggies, and dairy.  ',
#        'i would say my ideal diet is my current diet',
#        'Healthy, fresh veggies/fruits & organic foods ',
#        'Ideally I would like to be able to eat healthier foods in order to loose weight. ',
#        'My ideal diet is to eat 3 times a day including breakfast on time. Eat healthy food. ',
#        'I would ideally like to eat more fresh fruits and vegetables. However, its difficult to get to the store all the time to buy fresh.',
#        'My ideal diet is filled with a lot of fruit and chicken. I also really enjoy eggs any type of way with toast.',
#        'The same as it is now.',
#        'Lots of protein, carbs, and fruits and veggies. ',
#        'Chicken, fish ', 'More healthy varienty. ',
# ...

# %%
df["ideal_diet"].nunique()
# Out:
# 124

# %%
df["ideal_diet"].mode()
# Out:
# 0                   3 healthy meals a day. No caffiene.
# 1                                  3 smaller meals a day
# 2      A balance between meats and vegetables with le...
# 3      A balanced diet with each food group. Getting ...
# 4          A good breakfast. A healthy lunch and dinner.
#                              ...
# 119    it would be a vegetarian diet without any red ...
# 120                                      lots of veggies
# 121    more healthy food such as vegetables than bad ...
# 122    my ideal diet would be more fruits and vegetab...
# 123    organic/healthy. fruits and vegetables but sti...
# Name: ideal_diet, Length: 124, dtype: object

# %%
df["ideal_diet"] = df["ideal_diet"].fillna(method = 'bfill')

# %%
df["ideal_diet"].unique()
# Out:
# array(['being healthy ',
#        'Try to eat 5-6 small meals a day. While trying to properly distribute carbs, protein, fruits, veggies, and dairy.  ',
#        'i would say my ideal diet is my current diet',
#        'Healthy, fresh veggies/fruits & organic foods ',
#        'Ideally I would like to be able to eat healthier foods in order to loose weight. ',
#        'My ideal diet is to eat 3 times a day including breakfast on time. Eat healthy food. ',
#        'I would ideally like to eat more fresh fruits and vegetables. However, its difficult to get to the store all the time to buy fresh.',
#        'My ideal diet is filled with a lot of fruit and chicken. I also really enjoy eggs any type of way with toast.',
#        'The same as it is now.',
#        'Lots of protein, carbs, and fruits and veggies. ',
#        'Chicken, fish ', 'More healthy varienty. ',
# ...

# %%
df["ideal_diet"].nunique()
# Out:
# 124

# %%
df["ideal_diet"].isna().sum()
# Out:
# 0

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["ideal_diet"] = le.fit_transform(df[["ideal_diet"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df['income'].unique()
# Out:
# array([5.        , 4.        , 6.        , 1.        , 3.        ,
#        2.        , 4.53225806])

# %%
mmm('income')
# Out:
# 0    6.0
# Name: income, dtype: float64
# 5.0
# 4.532258064516129

# %%
df["income"] = df["income"].fillna(df["income"].mean())

# %%
df["life_rewarding"] = df["life_rewarding"].fillna(method='bfill')

# %%
df["marital_status"].unique()
# Out:
# array([ 1.,  2.,  4., nan])

# %%
df["marital_status"] = df["marital_status"].fillna(method='ffill')

# %%
df["marital_status"].nunique()
# Out:
# 3

# %%
df["mother_education"] = df["mother_education"].fillna(method='ffill')

# %%
df["meals_dinner_friend"] = df["meals_dinner_friend"].fillna(method='ffill')

# %%
df["mother_profession"] = df["mother_profession"].fillna(method='ffill')

# %%
df["on_off_campus"] = df["on_off_campus"].fillna(method='ffill')

# %%
df["self_perception_weight"] = df["self_perception_weight"].fillna(method='ffill')

# %%
df["soup"] = df["soup"].fillna(method='ffill')

# %%
df["sports"] = df["sports"].fillna(method='ffill')

# %%
df["persian_food"] = df["persian_food"].fillna(method='ffill')

# %%
df["tortilla_calories"] = df["tortilla_calories"].fillna(method='ffill')

# %%
df["type_sports"] = df["type_sports"].fillna(method='ffill')

# %%
df["weight"] = df["weight"].fillna(method='ffill')

# %%
                1
turkey_calories                  0
type_sports                     21
veggies_day                      0
vitamins                         0
waffle_calories                  0
weight

# %%
df.isna().sum()
# Out:
# GPA                             0
# Gender                          0
# breakfast                       0
# calories_chicken                0
# calories_day                    0
# calories_scone                  0
# coffee                          0
# comfort_food                    0
# comfort_food_reasons            0
# comfort_food_reasons_coded      0
# cook                            0
# comfort_food_reasons_coded.1    0
# cuisine                         0
# diet_current                    0
# diet_current_coded              0
# drink                           0
# eating_changes                  0
# eating_changes_coded            0
# eating_changes_coded1           0
# eating_out                      0
# employment                      0
# ethnic_food                     0
# exercise                        0
# father_education                0
# father_profession               0
# fav_cuisine                     0
# fav_cuisine_coded               0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["weight"] = le.fit_transform(df[["weight"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le = LabelEncoder()
df["type_sports"] = le.fit_transform(df[["type_sports"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le = LabelEncoder()
df["mother_profession"] = le.fit_transform(df[["mother_profession"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
le = LabelEncoder()
df["meals_dinner_friend"] = le.fit_transform(df[["meals_dinner_friend"]])
# Out:
# C:\python 3.10\lib\site-packages\sklearn\preprocessing\_label.py:116: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125 entries, 0 to 124
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   GPA                           125 non-null    float64
#  1   Gender                        125 non-null    int64
#  2   breakfast                     125 non-null    int64
#  3   calories_chicken              125 non-null    int64
#  4   calories_day                  125 non-null    float64
#  5   calories_scone                125 non-null    float64
#  6   coffee                        125 non-null    int64
#  7   comfort_food                  125 non-null    int32
#  8   comfort_food_reasons          125 non-null    int32
#  9   comfort_food_reasons_coded    125 non-null    float64
#  10  cook                          125 non-null    float64
#  11  comfort_food_reasons_coded.1  125 non-null    int64
# ...

# %%
from sklearn.preprocessing import scale

# %%
df_clone = df.copy()

# %%
x = df_clone.values
x_std = scale(x)
x_std
# Out:
# array([[-2.66580169,  1.2453997 , -0.3551424 , ..., -1.02429504,
#          0.9754899 ,  0.98195986],
#        [ 0.61590039, -0.80295507, -0.3551424 , ...,  0.97628121,
#         -0.70012396, -0.12885446],
#        [-0.31051311, -0.80295507, -0.3551424 , ..., -1.02429504,
#         -0.70012396,  2.00020633],
#        ...,
#        [ 1.2125735 , -0.80295507, -0.3551424 , ...,  0.97628121,
#          0.9754899 , -1.42480451],
#        [-1.0956093 ,  1.2453997 , -0.3551424 , ..., -1.02429504,
#          0.9754899 , -0.77682948],
#        [ 1.25967927, -0.80295507, -0.3551424 , ...,  0.97628121,
#         -2.01235169, -0.77682948]])

# %%
scale = pd.DataFrame(x_std,columns=df.columns)

# %%
scale
# Out:
#               GPA    Gender  breakfast  calories_chicken  calories_day  \
# 0   -2.665802e+00  1.245400  -0.355142         -1.127263      0.549441
# 1    6.159004e-01 -0.802955  -0.355142          0.250061     -0.145462
# 2   -3.105131e-01 -0.802955  -0.355142          1.091758      1.514392
# 3   -5.722118e-01 -0.802955  -0.355142         -1.127263     -0.145462
# 4    2.128843e-01 -0.802955  -0.355142          1.091758     -1.805316
# 5   -3.058350e+00 -0.802955  -0.355142          0.250061     -0.145462
# 6    9.979805e-01  1.245400  -0.355142          0.250061     -0.145462
# 7   -3.105131e-01 -0.802955  -0.355142          1.091758     -0.145462
# 8   -3.105131e-01 -0.802955  -0.355142         -1.127263      0.549441
# 9   -3.105131e-01 -0.802955  -0.355142         -1.127263     -0.145462
# 10   2.128843e-01 -0.802955  -0.355142          0.250061     -0.145462
# 11   1.270147e+00 -0.802955  -0.355142          1.091758      1.514392
# ...
